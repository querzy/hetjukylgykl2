# %% [markdown]
# <a href="https://colab.research.google.com/github/querzy/hello-world/blob/master/fbprophet_4H_prediction_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ecad612a-af50-46ee-97c0-1653bf8977ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecad612a-af50-46ee-97c0-1653bf8977ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AUDCAD240.csv to AUDCAD240.csv
# Saving AUDCHF240.csv to AUDCHF240.csv
# Saving AUDJPY240.csv to AUDJPY240.csv
# Saving AUDNZD240.csv to AUDNZD240.csv
# Saving AUDUSD240.csv to AUDUSD240.csv
# Saving BTCUSD240.csv to BTCUSD240.csv
# Saving CADCHF240.csv to CADCHF240.csv
# Saving CADJPY240.csv to CADJPY240.csv
# Saving DOLLAR_INDX240.csv to DOLLAR_INDX240.csv
# Saving EURAUD240.csv to EURAUD240.csv
# Saving EURCAD240.csv to EURCAD240.csv
# Saving EURCHF240.csv to EURCHF240.csv
# Saving EURGBP240.csv to EURGBP240.csv
# Saving EURJPY240.csv to EURJPY240.csv
# Saving EURNZD240.csv to EURNZD240.csv
# Saving EURUSD240.csv to EURUSD240.csv
# Saving GBPAUD240.csv to GBPAUD240.csv
# Saving GBPCAD240.csv to GBPCAD240.csv
# Saving GBPCHF240.csv to GBPCHF240.csv
# Saving GBPJPY240.csv to GBPJPY240.csv
# Saving GBPNZD240.csv to GBPNZD240.csv
# Saving GBPUSD240.csv to GBPUSD240.csv
# Saving NZDCAD240.csv to NZDCAD240.csv
# Saving NZDCHF240.csv to NZDCHF240.csv
# Saving NZDJPY240.csv to NZDJPY240.csv
# Saving NZDUSD240.csv to NZDUSD240.csv
# Saving USDCAD240.csv to USDCAD240.csv
# Saving USDCHF240.csv to USDCHF240.csv
# Saving USDJPY240.csv to USDJPY240.csv
# Saving USDTRY240.csv to USDTRY240.csv
# Saving XAGUSD240.csv to XAGUSD240.csv
# Saving XAUUSD240.csv to XAUUSD240.csv

# %%
import pandas as pd
from pandas import read_csv
from pandas import to_datetime
from pandas import DataFrame
from datetime import datetime
from fbprophet import Prophet
from matplotlib import pyplot

def extractDigits(lst): 
    return [[el] for el in lst] 

def get_num(xx):
    return int(''.join(ele for ele in xx if ele.isdigit()))

fileLst=['UsDollar240.csv','EURUSD240.csv','GBPUSD240.csv','AUDUSD240.csv','USDJPY240.csv','USDCAD240.csv','NZDUSD240.csv','USDCHF240.csv','GBPJPY240.csv','CADJPY240.csv',
'EURJPY240.csv','EURGBP240.csv','GBPNZD240.csv','AUDJPY240.csv','NZDJPY240.csv','USDTRY240.csv','XAGUSD240.csv','XAUUSD240.csv']

#fileLst=['UsDollar240.csv']
         

for file in fileLst :
    valperiod=get_num(file)
    filename1 = datetime.now().strftime("%d %b %Y - %H%M")
    print(filename1)
    filename=file.replace('.csv','')
    parite=filename.replace(str(valperiod),'')
    print(parite)
    print(valperiod)
    print('  ')
    df = pd.read_csv(file)
    #df=df[-500:]
    df.head(5)

    df.describe()

    # Select only the important features i.e. the date and price
    df = df[["Date","Close"]] # select Date and Price# Rename the features: These names are NEEDED for the model fitting
    df = df.rename(columns = {"Date":"ds","Close":"y"}) #renaming the columns of the datasetdata.head(5)

    df.columns =['ds','y']

    df['ds']=to_datetime(df['ds'])

    model=Prophet()

    model.fit(df)

    future = pd.date_range(start ='2021.03.05 22:00',  
            end ='2021.06.05 06:00', freq ='4H') 
      
    #future = pd.date_range(start ='2021.03.05 21:00',  
    #        end ='2021.06.05 06:00', freq ='4H') 
    
    future = future[future.dayofweek < 5]#RETIRER WEEKENDS
    
