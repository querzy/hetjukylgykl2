# %% [markdown]
# <a href="https://colab.research.google.com/github/querzy/hello-world/blob/master/TimeseriesGenerator_future_prices_weekly_t_1_SOOQ_PARITE_PARAMETERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a4dafe2-f036-4e96-bdff-889512b7b6c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a4dafe2-f036-4e96-bdff-889512b7b6c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving usdtry_w10080.csv to usdtry_w10080.csv
# Saving xagusd_w10080.csv to xagusd_w10080.csv
# Saving xauusd_w10080.csv to xauusd_w10080.csv
# Saving nzdcad_w10080.csv to nzdcad_w10080.csv
# Saving nzdchf_w10080.csv to nzdchf_w10080.csv
# Saving nzdjpy_w10080.csv to nzdjpy_w10080.csv
# Saving audcad_w10080.csv to audcad_w10080.csv
# Saving audchf_w10080.csv to audchf_w10080.csv
# Saving audjpy_w10080.csv to audjpy_w10080.csv
# Saving audnzd_w10080.csv to audnzd_w10080.csv
# Saving gbpaud_w10080.csv to gbpaud_w10080.csv
# ...

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import LSTM, Dense
import plotly.offline as pyoff
import plotly.graph_objs as go
import random as rn
import os
 
os.environ['PYTHONHASHSEED'] = '0'
 
# Setting the seed for numpy-generated random numbers
np.random.seed(37)
 
# Setting the seed for python random numbers
rn.seed(1254)
 
# Setting the graph-level random seed.
tf.random.set_seed(89)
 
def get_num(xx):
    return int(''.join(ele for ele in xx if ele.isdigit()))
    
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Date'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates
    
#fileLst=['eurusd_d1440.csv','gbpusd_d1440.csv','audusd_d1440.csv','usdjpy_d1440.csv','usdcad_d1440.csv','nzdusd_d1440.csv','usdchf_d1440.csv','gbpjpy_d1440.csv','cadjpy_d1440.csv','cadchf_d1440.csv','euraud_d1440.csv',
#'eurjpy_d1440.csv','eurgbp_d1440.csv','eurchf_d1440.csv','eurcad_d1440.csv','eurnzd_d1440.csv','gbpnzd_d1440.csv','gbpchf_d1440.csv','gbpcad_d1440.csv','gbpaud_d1440.csv','audnzd_d1440.csv','audjpy_d1440.csv',
#'audchf_d1440.csv','audcad_d1440.csv','nzdjpy_d1440.csv','nzdchf_d1440.csv','nzdcad_d1440.csv','usdtry_d1440.csv','xagusd_d1440.csv','xauusd_d1440.csv']

#fileLst=['eurusd_w10080.csv','gbpusd_w10080.csv','audusd_w10080.csv','usdjpy_w10080.csv','usdcad_w10080.csv','nzdusd_w10080.csv','usdchf_w10080.csv','gbpjpy_w10080.csv','cadjpy_w10080.csv','cadchf_w10080.csv','euraud_w10080.csv',
'audchf_w','audcad_w','nzdjpy_w','nzdchf_w','nzdcad_w','usdtry_w','xagusd_w','xauusd_w']

#WeeklyStooq=['eurcad_w','usdtry_w','gbpnzd_w','eurchf_w']
#WeeklyStooq2=['gbpaud_w','audchf_w', 'gbpchf_w','xauusd_w']
#WeeklyStooq3=['gbpusd_w','gbpcad_w','audcad_w']
#WeeklyStooq4=['usdjpy_w','xagusd_w','audjpy_w']     
#WeeklyStooq5=['gbpusd_w','nzdusd_w','euraud_w','eurjpy_w','audnzd_w']
#WeeklyStooq6=['eurusd_w','audusd_w','usdchf_w','eurgbp_w','nzdjpy_w','nzdchf_w','nzdcad_w'] 
#WeeklyStooq7=['usdcad_w','cadchf_w','cadjpy_w']    
#WeeklyStooq8=['gbpjpy_w','eurnzd_w']

with open('/content/recap deep learning generator weekly stooq t-1.txt', 'w') as document: pass

filedate = datetime.now().strftime("%d %b %Y - %H%M")

with open('/content/recap deep learning generator weekly stooq t-1.txt', 'a') as f:
  f.write(filedate  + '\n')

for file in fileLst :
  #file = 'EURJPY1440.csv'
  valperiod=get_num(file)
  filename1 = datetime.now().strftime("%d %b %Y - %H%M")
  filename=file.replace('.csv','')
  parite=filename.replace(str(valperiod),'')
  print(parite)
  print(valperiod)
  df = pd.read_csv(file, skipfooter=1, engine='python')
  #print(df.info())
  PRICECLOSED = df['Close'].iloc[-1]
  df['Date'] = pd.to_datetime(df['Date'])
  df.set_axis(df['Date'], inplace=True)
  df.drop(columns=['Open', 'High', 'Low'], inplace=True)

  close_data = df['Close'].values
  close_data = close_data.reshape((-1,1))

  split_percent = 0.80
  split = int(split_percent*len(close_data))

  close_train = close_data[:split]
  close_test = close_data[split:]

  date_train = df['Date'][:split]
  date_test = df['Date'][split:]

  print(len(close_train))
  print(len(close_test))

  look_back = 15

  #if parite == 'UsDollar' :
  # train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=1)     
  #test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)
  #model = Sequential()
  #model.add(LSTM(200, input_shape=(look_back,1)))
  #model.add(Dense(1))
  #model.compile(loss='mean_squared_error', optimizer='adam')
  #model.fit(train_generator, epochs=20, verbose=1)
  if parite in WeeklyStooq :
    batch_size=1 #DEFAUT
    epochs=5 #DEFAUT
    val_lstm=200 #DEFAUT
    train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=batch_size)     
    test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)
    model = Sequential()
    model.add(LSTM(val_lstm, input_shape=(look_back,1)))#DEFAUT
    #model.add(LSTM(500, input_shape=(look_back,1)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(train_generator, epochs=epochs, verbose=1)#DEFAUT
    #model.fit(train_generator, epochs=10, verbose=1)
#    if parite == 'UsDollar' :
#      model.fit(trainX, trainY, epochs=20, batch_size=1, verbose=1)#default DXY
#    elif parite in WeeklyStooq :
#      model.fit(trainX, trainY, epochs=5, batch_size=1, verbose=1)
#    elif parite in WeeklyStooq2 :
#      model.fit(trainX, trainY, epochs=5, batch_size=2, verbose=1)
#    elif parite in WeeklyStooq3 :
#      model.fit(trainX, trainY, epochs=5, batch_size=5, verbose=1)
#    elif parite in WeeklyStooq4 :
#      model.fit(trainX, trainY, epochs=5, batch_size=10, verbose=1)
#    elif parite in WeeklyStooq5 :    
#      model.fit(trainX, trainY, epochs=25, batch_size=1, verbose=1) 
#    elif parite in WeeklyStooq6 :    
#      model.fit(trainX, trainY, epochs=20, batch_size=1, verbose=1)    
#    elif parite in WeeklyStooq7 :    
#     model.fit(trainX, trainY, epochs=20, batch_size=2, verbose=1)
#    elif parite in WeeklyStooq8 :    
#      model.fit(trainX, trainY, epochs=20, batch_size=10, verbose=1)
#    else :
#      #model.fit(trainX, trainY, epochs=5, batch_size=1, verbose=1)#default EURUSD OANDA
#      #model.fit(trainX, trainY, epochs=5, batch_size=5, verbose=1)#stooq weekly
#      model.fit(trainX, trainY, epochs=5, batch_size=10, verbose=1)#stooq weekly
#      #model.fit(trainX, trainY, epochs=10, batch_size=10, verbose=1)#stooq weekly***************
#      #model.fit(trainX, trainY, epochs=5, batch_size=20, verbose=1)#stooq weekly
#      #model.fit(trainX, trainY, epochs=5, batch_size=20, verbose=1)#stooq daily
#      #model.fit(trainX, trainY, epochs=5, batch_size=10, verbose=1)#stooq daily****************
#      #model.fit(trainX, trainY, epochs=5, batch_size=32, verbose=1)#stooq daily
#      #model.fit(trainX, trainY, epochs=20, batch_size=1, verbose=1)#

    prediction = model.predict(test_generator)

    close_train = close_train.reshape((-1))
    close_test = close_test.reshape((-1))
    prediction = prediction.reshape((-1))

    plot_data = [
          go.Scatter(
            x = date_train,
            y = close_train,
            mode = 'lines',
            name = 'Data'
          ),
          go.Scatter(
            x = date_test,
            y = prediction,
            mode = 'lines',
            name = 'Prediction'
          ),
          go.Scatter(
            x = date_test,
            y = close_test,
            mode='lines',
            name = 'Ground Truth'
          )
        ]
      
    plot_layout = go.Layout(title = parite+' '+str(valperiod),
        xaxis = {'title' : "Date"},
        yaxis = {'title' : "Close"}
      )

    fig = go.Figure(data=plot_data, layout=plot_layout)
    #fig.show()
    pyoff.iplot(fig)

    close_data = close_data.reshape((-1))



    num_prediction = 30
    forecast = predict(num_prediction, model)
    forecast_dates = predict_dates(num_prediction)

    #print('prediction ',prediction)
    #print('close_test ',close_test)
    futurePredict=round(forecast[1],5)
    diff=prediction[-1]-close_test[-2]
    print('diff : ',diff)
    if diff > 0.0 :
      aprox=futurePredict - abs(diff)
    else :
      aprox=futurePredict + abs(diff)

    
    futurprice=str(round(forecast[1],5))

    print(forecast_dates)
    print(forecast)
    print('  ')
    print("Last bar closed: ")
    print(PRICECLOSED)
    print("Price for tomorrow : ")
    print(futurprice + ' plus ou moins la difference pips du premier graphique')
    print('REGARDER LA DIFFERENCE EN PIPS SUR LE PREMIER GRAPHIQUE')
    print('ETUDIER LE CAS WeeklyStooq QUI PARAIT PLUS PRECIS BACH SIZE 1 !!!!!!!!!!!!!!!')
    print(' ')
    print("Aproximation : ",str(round(aprox,5)))

    plot_data = [
          #go.Scatter(
            # x = date_train[-30:],
            #y = close_train[-30:],
            #mode = 'lines',
            #name = 'Data'
          #),
          go.Scatter(
            x = date_test[-30:],
            y = close_test[-30:],
            mode='lines',
            name = 'Data'
          ),
          go.Scatter(
            x = forecast_dates,
            y = forecast,
            mode = 'lines',
            name = 'Forecast'
          )
        ]
      
    plot_layout = go.Layout(title = parite+' '+str(valperiod),
        xaxis = {'title' : "Date"},
        yaxis = {'title' : "Close"}
      )

    fig = go.Figure(data=plot_data, layout=plot_layout)
    #fig.show()
    pyoff.iplot(fig)

    with open('/content/recap deep learning generator weekly stooq t-1.txt', 'a') as f:
      f.write(' '  + '\n')
      f.write(parite + ' ' + str(valperiod) + '\n')
      f.write(' ' + '\n')
      f.write('batch_size ' + str(batch_size))
      f.write('val_lstm ' + str(val_lstm))
      f.write('epochs ' + str(epochs))
      f.write(' ' + '\n')
      f.write('Closed price : ' + str(PRICECLOSED)+ '\n')
      f.write(' ' + '\n')
      f.write('Price for tomorrow : ' + futurprice + ' plus ou moins la difference pips du premier graphique'+ '\n')
      f.write('diff #####: ' +str(round(diff,5)) + '\n') 
      f.write(' '  + '\n')
      f.write('Aproximation : ' + str(round(aprox,5))  + '\n')
      f.write(' '  + '\n')
      f.write('§§§§§§§§§§§§§'  + '\n')
      
files.download('/content/recap deep learning generator weekly stooq t-1.txt')
f.close()
# Out:
# eurusd_w
# 10080
# 2093
# 524
# Epoch 1/10
# 2078/2078 [==============================] - 74s 35ms/step - loss: 0.0136
# Epoch 2/10
# 2078/2078 [==============================] - 73s 35ms/step - loss: 0.0012
# Epoch 3/10
# 2078/2078 [==============================] - 73s 35ms/step - loss: 8.9385e-04
# Epoch 4/10
# 2078/2078 [==============================] - 73s 35ms/step - loss: 6.4905e-04
# Epoch 5/10
# 2078/2078 [==============================] - 73s 35ms/step - loss: 5.7404e-04
# Epoch 6/10
# 2078/2078 [==============================] - 72s 35ms/step - loss: 5.5373e-04
# Epoch 7/10
# 2078/2078 [==============================] - 72s 35ms/step - loss: 5.7469e-04
# Epoch 8/10
# 2078/2078 [==============================] - 72s 34ms/step - loss: 5.6517e-04
# Epoch 9/10
# 2078/2078 [==============================] - 72s 35ms/step - loss: 4.3762e-04
# Epoch 10/10
# 2078/2078 [==============================] - 73s 35ms/step - loss: 5.0608e-04
# <html>
# ...
