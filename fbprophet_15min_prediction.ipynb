# %% [markdown]
# <a href="https://colab.research.google.com/github/querzy/hello-world/blob/master/fbprophet_15min_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b5f5b5fa-1669-43a1-91cf-04afe7a70343" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5f5b5fa-1669-43a1-91cf-04afe7a70343">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving UsDollar15.csv to UsDollar15.csv

# %%
import pandas as pd
from pandas import read_csv
from pandas import to_datetime
from pandas import DataFrame
from datetime import datetime
from fbprophet import Prophet
from matplotlib import pyplot

def extractDigits(lst): 
    return [[el] for el in lst] 

def get_num(xx):
    return int(''.join(ele for ele in xx if ele.isdigit()))

fileLst=['UsDollar15.csv','EURUSD15.csv','GBPUSD15.csv','AUDUSD15.csv','USDJPY15.csv','USDCAD15.csv','NZDUSD15.csv','USDCHF15.csv','GBPJPY15.csv','CADJPY15.csv',
'EURJPY15.csv','EURGBP15.csv','GBPNZD15.csv','AUDJPY15.csv','NZDJPY15.csv','USDTRY15.csv','XAGUSD15.csv','XAUUSD15.csv']

#fileLst=['UsDollar240.csv']
         

for file in fileLst :
    valperiod=get_num(file)
    filename1 = datetime.now().strftime("%d %b %Y - %H%M")
    print(filename1)
    filename=file.replace('.csv','')
    parite=filename.replace(str(valperiod),'')
    print(parite)
    print(valperiod)
    print('  ')
    df = pd.read_csv(file)
    #df=df[-500:]
    df.head(5)

    df.describe()

    # Select only the important features i.e. the date and price
    df = df[["Date","Close"]] # select Date and Price# Rename the features: These names are NEEDED for the model fitting
    df = df.rename(columns = {"Date":"ds","Close":"y"}) #renaming the columns of the datasetdata.head(5)

    df.columns =['ds','y']

    df['ds']=to_datetime(df['ds'])

    model=Prophet()

    model.fit(df)

    future = pd.date_range(start ='2021.03.05 20:30',  
            end ='2021.06.05 06:00', freq ='4H') 
      
    #future = pd.date_range(start ='2021.03.05 21:00',  
    #        end ='2021.06.05 06:00', freq ='4H') 
    
    future = future[future.dayofweek < 5]#RETIRER WEEKENDS
    
    future = future.strftime('%Y.%m.%d %H:%M').tolist()

    future = extractDigits(future)

    future=DataFrame(future)

    future.columns=['ds']

    future['ds']=to_datetime(future['ds'])
    future2 = model.make_future_dataframe(periods=1060, freq='15min')
    #forecast = model.predict(future)
    forecast = model.predict(future2)
    print(forecast[['ds','yhat','yhat_lower','yhat_upper']].head())

    model.plot(forecast)

    pyplot.title(parite+' '+str(valperiod))

    pyplot.show()
# Out:
# 06 Mar 2021 - 1618
# UsDollar
# 15
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
#                    ds       yhat  yhat_lower  yhat_upper
# 0 2021-01-15 23:15:00  90.816983   90.658451   90.979314
# 1 2021-01-15 23:30:00  90.813597   90.641679   90.973505
# 2 2021-01-15 23:45:00  90.810227   90.660674   90.955680
# 3 2021-01-18 03:30:00  90.743892   90.571488   90.906943
# 4 2021-01-18 03:45:00  90.748875   90.596745   90.908166
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 06 Mar 2021 - 1618
# EURUSD
# 15
#
#                    ds      yhat  yhat_lower  yhat_upper
# 0 2020-12-22 19:45:00